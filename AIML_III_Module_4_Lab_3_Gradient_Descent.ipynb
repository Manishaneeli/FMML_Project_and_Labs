# %% [markdown]
# <a href="https://colab.research.google.com/github/Manishaneeli/FMML_Project_and_Labs/blob/main/AIML_III_Module_4_Lab_3_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Students Internship Batch of 2024
# # Module 4: Perceptron and Gradient Descent
# ## Lab 3: Gradient Descent
#
# Gradient descent is a very important algorithm to understand, as it underpins many of the more advanced algorithms used in Machine Learning and Deep Learning.
#
# A brief overview of the algorithm is
#
#
# *   start with a random initialization of the solution.
# *   incrementally change the solution by moving in the direction of negative gradient of the objective function.
# *   repeat the previous step until some convergence criteria is met.
#
# The key equation for change in weight is:
# $$w^{k+1} \leftarrow w^k - \eta \Delta J$$
#
# In this lab, we will discuss stochastic gradient descent, mini-batch gradient descent and batch gradient descent.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# # Creating the Data
#
# Let's generate some data with:
# \begin{equation} y_0= 4 \end{equation}
# \begin{equation} y_1= 3 \end{equation}
#
# and also add some noise to the data.

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# Let's also plot the data we just created

# %%
plt.plot(X, y, 'b.')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Cost Function
#
# The equation for calculating cost function is as shown below. The cost function is only for linear regression. For other algorithms, the cost function will be different and the gradients would have to be derived from the cost functions
#
# \begin{equation}
# J(y_{pred}) = \frac{1}{2} m \sum_{i=1}^{m} (h(y_{pred})^{(i)} - y^{(i)})^2
# \end{equation}

# %%
def cal_cost(y_pred, X, y):
    '''
    Calculates the cost for given X and Y.
    y_pred = Vector of y_preds
    X = Row of X's np.zeros((2, j))
    y = Actual y's np.zeros((2, 1))

    where:
        j is the no of features
    '''

    m = len(y)

    predictions = X.dot(y_pred)
    cost = (1 / 2 * m) * np.sum(np.square(predictions - y))

    return cost

# %% [markdown]
# ## Gradients
#
# \begin{equation}
# y_{pred_0}: = y_{pred_0} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# \begin{equation}
# y_{pred_1}: = y_{pred_1} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# .
#
# .
#
# .
#
# .
#
# \begin{equation}
# y_{pred_j}: = y_{pred_j} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}

# %%
def gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    y_pred_history = np.zeros((iterations, 2))

    for it in range(iterations):
        prediction = np.dot(X, y_pred)
        y_pred = y_pred - (1 / m) * learning_rate * (X.T.dot((prediction - y)))
        y_pred_history[it,:] = y_pred.T
        cost_history[it]  = cal_cost(y_pred, X, y)

    return y_pred, cost_history, y_pred_history

# %% [markdown]
# Let's do 1000 iterations with a learning rate of 0.01.
# We will start with a random prediction.

# %%
lr = 0.01
n_iter = 1000

y_pred = np.random.randn(2,1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history, y_pred_history = gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 3.903
# y_pred[1]: 3.046
# Final error: 4180.375

# %% [markdown]
# Plotting the error vs Number of iterations

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Zooming in...

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(range(200), cost_history[:200], 'b.')

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# In Batch Gradient Descent we were considering all the examples for every step of Gradient Descent. But what if our dataset is very huge. Deep learning models crave for data. The more the data the more chances of a model to be good. Suppose our dataset has 5 million examples, then just to take one step the model will have to calculate the gradients of all the 5 million examples. This does not seem an efficient way. To tackle this problem we have Stochastic Gradient Descent. In Stochastic Gradient Descent (SGD), we consider just one example at a time to take a single step.

# %%
def stocashtic_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_pred np.random.randn(j,1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)

    for it in range(iterations):
        cost = 0.0

        for i in range(m):
            rand_ind = np.random.randint(0,m)
            X_i = X[rand_ind, :].reshape(1, X.shape[1])
            y_i = y[rand_ind].reshape(1,1)
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate *(X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.5
n_iter = 50
y_pred = np.random.randn(2, 1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.121
# y_pred[1]: 2.755
# Final error: 41.313

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# # Mini Batch Gradient Descent

# %% [markdown]
# We have seen the Batch Gradient Descent. We have also seen the Stochastic Gradient Descent. Batch Gradient Descent can be used for smoother curves. SGD can be used when the dataset is large. Batch Gradient Descent converges directly to minima. SGD converges faster for larger datasets. But, since in SGD we use only one example at a time, we cannot implement the vectorized implementation on it. This can slow down the computations. To tackle this problem, a mixture of Batch Gradient Descent and SGD is used.
# Neither we use all the dataset all at once nor we use the single example at a time. We use a batch of a fixed number of training examples which is less than the actual dataset and call it a mini-batch. Doing this helps us achieve the advantages of both the former variants we saw.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10, batch_size=20):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final theta vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)

    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones(len(X_i)), X_i]
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.148
# y_pred[1]: 2.827
# Final error: 807.488

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Things to try out:
#
# 1. Change batch size in mini-batch gradient descent.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10, batch_size=32)

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)

    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones(len(X_i)), X_i]
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.248
# y_pred[1]: 2.741
# Final error: 1260.565

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# ###2. Test all the three out on real datasets.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# Load California housing dataset
california = fetch_california_housing()
X_california = california.data
y_california = california.target.reshape(-1, 1)

# Standardize the dataset
scaler = StandardScaler()
X_california_scaled = scaler.fit_transform(X_california)

# Adding bias term (intercept)
X_california_scaled = np.c_[np.ones((len(X_california_scaled), 1)), X_california_scaled]

# Gradient Descent Functions
def cal_cost(y_pred, X, y):
    '''
    X: Feature matrix
    y: Actual target values
    y_pred: Predicted target values
    '''
    m = len(y)
    return (1/(2 * m)) * np.sum(np.square(np.dot(X, y_pred) - y))

def gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    m = len(y)
    cost_history = np.zeros(iterations)
    y_pred_history = np.zeros((iterations, X.shape[1]))  # Corrected to match feature size

    for it in range(iterations):
        prediction = np.dot(X, y_pred)
        y_pred = y_pred - (1 / m) * learning_rate * (X.T.dot((prediction - y)))
        y_pred_history[it, :] = y_pred.T  # Now it matches the feature size
        cost_history[it] = cal_cost(y_pred, X, y)

    return y_pred, cost_history, y_pred_history

def stochastic_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    m = len(y)
    cost_history = np.zeros(iterations)

    for it in range(iterations):
        for i in range(m):
            random_index = np.random.randint(m)
            X_i = X[random_index:random_index+1]
            y_i = y[random_index:random_index+1]
            prediction = np.dot(X_i, y_pred)
            y_pred = y_pred - learning_rate * X_i.T.dot((prediction - y_i))

        cost_history[it] = cal_cost(y_pred, X, y)

    return y_pred, cost_history

def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100, batch_size=20):
    m = len(y)
    cost_history = np.zeros(iterations)

    for it in range(iterations):
        indices = np.random.permutation(m)
        X_shuffled = X[indices]
        y_shuffled = y[indices]

        for i in range(0, m, batch_size):
            X_i = X_shuffled[i:i+batch_size]
            y_i = y_shuffled[i:i+batch_size]
            prediction = np.dot(X_i, y_pred)
            y_pred = y_pred - (1 / len(y_i)) * learning_rate * X_i.T.dot((prediction - y_i))

        cost_history[it] = cal_cost(y_pred, X, y)

    return y_pred, cost_history

# Parameters for Gradient Descent
lr = 0.01
n_iter = 500

# Batch Gradient Descent
print("Batch Gradient Descent:")
y_pred_bgd = np.random.randn(X_california_scaled.shape[1], 1)
y_pred_bgd, cost_history_bgd, _ = gradient_descent(X_california_scaled, y_california, y_pred_bgd, lr, n_iter)
print('Final error (Batch Gradient Descent):', cost_history_bgd[-1])

# Plotting BGD
plt.plot(range(n_iter), cost_history_bgd, 'b.')
plt.title('Batch Gradient Descent')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.show()

# Stochastic Gradient Descent
print("Stochastic Gradient Descent:")
y_pred_sgd = np.random.randn(X_california_scaled.shape[1], 1)
y_pred_sgd, cost_history_sgd = stochastic_gradient_descent(X_california_scaled, y_california, y_pred_sgd, lr, n_iter)
print('Final error (Stochastic Gradient Descent):', cost_history_sgd[-1])

# Plotting SGD
plt.plot(range(n_iter), cost_history_sgd, 'r.')
plt.title('Stochastic Gradient Descent')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.show()

# Mini-Batch Gradient Descent
print("Mini-Batch Gradient Descent:")
batch_size = 20
y_pred_mbgd = np.random.randn(X_california_scaled.shape[1], 1)
y_pred_mbgd, cost_history_mbgd = minibatch_gradient_descent(X_california_scaled, y_california, y_pred_mbgd, lr, n_iter, batch_size)
print('Final error (Mini-Batch Gradient Descent):', cost_history_mbgd[-1])

# Plotting MBGD
plt.plot(range(n_iter), cost_history_mbgd, 'g.')
plt.title('Mini-Batch Gradient Descent')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.show()
# Out:
# Batch Gradient Descent:
# Final error (Batch Gradient Descent): 0.3480271425303096
# Stochastic Gradient Descent:
# <ipython-input-22-92708ffb9ecd>:26: RuntimeWarning: overflow encountered in square
#   return (1/(2 * m)) * np.sum(np.square(np.dot(X, y_pred) - y))
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# <ipython-input-22-92708ffb9ecd>:51: RuntimeWarning: invalid value encountered in subtract
#   y_pred = y_pred - learning_rate * X_i.T.dot((prediction - y_i))
# Final error (Stochastic Gradient Descent): nan
# Mini-Batch Gradient Descent:
# Final error (Mini-Batch Gradient Descent): 0.263733682745333

# %% [markdown]
# ###3. Compare the effects of changing learning rate by the same amount in Batch GD, SGD and Mini-batch GD.

# %%
learning_rates = [0.001, 0.01, 0.1]
n_iter = 200

# Batch Gradient Descent for different learning rates
print("Batch Gradient Descent:")
for lr in learning_rates:
    y_pred = np.random.randn(2,1)
    y_pred, cost_history, _ = gradient_descent(X_b, y, y_pred, lr, n_iter)

    print(f'Learning Rate: {lr}')
    print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
    print('Final error: {:0.3f}'.format(cost_history[-1]))

    # Plotting
    plt.plot(range(n_iter), cost_history, label=f'LR: {lr}')

plt.title('Batch Gradient Descent - Error vs Iterations')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.legend()
plt.show()

# Stochastic Gradient Descent for different learning rates
print("Stochastic Gradient Descent:")
for lr in learning_rates:
    y_pred = np.random.randn(2,1)
    y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter)

    print(f'Learning Rate: {lr}')
    print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
    print('Final error: {:0.3f}'.format(cost_history[-1]))

    # Plotting
    plt.plot(range(n_iter), cost_history, label=f'LR: {lr}')

plt.title('Stochastic Gradient Descent - Error vs Iterations')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.legend()
plt.show()

# Mini-Batch Gradient Descent for different learning rates
print("Mini-Batch Gradient Descent:")
batch_size = 20
for lr in learning_rates:
    y_pred = np.random.randn(2,1)
    y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter, batch_size)

    print(f'Learning Rate: {lr}')
    print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
    print('Final error: {:0.3f}'.format(cost_history[-1]))

    # Plotting
    plt.plot(range(n_iter), cost_history, label=f'LR: {lr}')

plt.title('Mini-Batch Gradient Descent - Error vs Iterations')
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.legend()
plt.show()
# Out:
# Batch Gradient Descent:
# Learning Rate: 0.001
# y_pred[0]: 1.599
# y_pred[1]: 2.256
# Final error: 52534.705
# Learning Rate: 0.01
# y_pred[0]: 3.495
# y_pred[1]: 3.328
# Final error: 4769.075
# Learning Rate: 0.1
# y_pred[0]: 4.197
# y_pred[1]: 2.786
# Final error: 4033.429
# Stochastic Gradient Descent:
# Learning Rate: 0.001
# y_pred[0]: 1.349
# y_pred[1]: 1.327
# Final error: 952.566
# Learning Rate: 0.01
# y_pred[0]: 3.663
# y_pred[1]: 3.147
# Final error: 33.940
# Learning Rate: 0.1
# y_pred[0]: 4.196
# y_pred[1]: 2.735
# Final error: 45.329
# Mini-Batch Gradient Descent:
# Learning Rate: 0.001
# y_pred[0]: 2.281
# y_pred[1]: 0.792
# Final error: 16595.455
# Learning Rate: 0.01
# y_pred[0]: 3.876
# y_pred[1]: 2.960
# Final error: 845.319
# Learning Rate: 0.1
# y_pred[0]: 4.186
# y_pred[1]: 2.795
# Final error: 804.574

# %% [markdown]
# ## **Additional Critical Thinking Question**

# %% [markdown]
# **Which of the following is TRUE, given the optimal learning rate?**
#
#  (i) Batch gradient descent is always guaranteed to converge to the global optimum of a loss function.
#
#  (ii) Stochastic gradient descent is always guaranteed to converge to the global optimum of a loss function.
#
#  (iii) For convex loss functions (i.e. with a bowl shape), batch gradient descent is guaranteed to eventually converge to the global optimum while stochastic gradient descent is not.
#
#  (iv) For convex loss functions (i.e. with a bowl shape), stochastic gradient descent is guaranteed to eventually converge to the global optimum while batch gradient descent is not.
#
#  (v) For convex loss functions (i.e. with a bowl shape), both stochastic gradient descent and batch gradient descent will eventually converge to the global optimum.
#
#  (vi) For convex loss functions (i.e. with a bowl shape), neither stochastic gradient descent nor batch gradient descent are guaranteed to converge to the global optimum.

# %% [markdown]
# ##Answer
# **(v) For convex loss functions (i.e. with a bowl shape), both stochastic gradient descent and batch gradient descent will eventually converge to the global optimum.** is the true
#
# ### Explanation:
#
# - **Batch Gradient Descent (BGD)**: In the case of convex loss functions, batch gradient descent is guaranteed to converge to the global optimum, provided the learning rate is appropriately chosen. This is because, for convex functions, there is only one global minimum and no local minima.
#
# - **Stochastic Gradient Descent (SGD)**: SGD can also converge to the global optimum for convex loss functions, but it typically requires additional tuning (such as gradually reducing the learning rate). SGD's convergence is less smooth than BGD due to its random nature, but with proper conditions (like an appropriate learning rate schedule), it will still converge to the global optimum.
#
# Thus, for convex loss functions, both BGD and SGD can eventually converge to the global optimum with proper tuning.
